# %%
import pickle
import tkinter as tk
from tkinter import LabelFrame, Label,END, Tk,StringVar,LEFT,Entry,OptionMenu,W,Button,Text
import numpy as np
import pandas as pd
import random
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %%
file_name='randomforest.sav'
clf2=pickle.load(open(file_name,'rb'))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\Users\MANOHA~1\AppData\Local\Temp/ipykernel_21084/3328509870.py in <module>
#       1 file_name='randomforest.sav'
# ----> 2 clf2=pickle.load(open(file_name,'rb'))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'randomforest.sav'

# %%
import tkinter as tk
from tkinter import LabelFrame, Label,END, Tk,StringVar,LEFT,Entry,OptionMenu,W,Button,Text
def DecisionTree():
    '''from sklearn import tree
    clf1 = tree.DecisionTreeClassifier()   # empty model of the decision tree
    clf1 = clf1.fit(X,y)

    # calculating accuracy-------------------------------------------------------------------
    from sklearn.metrics import accuracy_score
    y_pred=clf1.predict(X_test)
    print("Accuracy for Decision Tree",accuracy_score(y_test, y_pred))
    print(accuracy_score(y_test, y_pred,normalize=False))'''
    # -----------------------------------------------------
    psymptoms = [Symptom1.get(),Symptom2.get(),Symptom3.get(),Symptom4.get(),Symptom5.get()]
    c=0
    for z in psymptoms:
        # print (k,)
        for k in range(0,len(l1)):
            if(z==l1[k]):
                l2[k]=1
                c+=1
    if(c!=0):
        inputtest = [l2]
        predict = clf1.predict(inputtest)
        predicted=predict[0]
        h='no'
        for a in range(0,len(disease)):
            if(predicted == a):
                h='yes'
                break
        if (h=='yes'):
            t1.delete("1.0", END)
            t1.insert(END, disease[a])
        else:
            t1.delete("1.0", END)
            t1.insert(END, "Not Found")
    else:
        t1.delete("1.0", END)
        t1.insert(END, "Select the Symptoms")
#-----Random Forest-----------------------------------------------------------------------------
def randomforest():
    '''from sklearn.ensemble import RandomForestClassifier
    clf2 = RandomForestClassifier()
    clf2 = clf2.fit(X,y)
    # calculating accuracy-------------------------------------------------------------------
    from sklearn.metrics import accuracy_score
    y_pred=clf2.predict(X_test)
    print("Accuracy for random forest",accuracy_score(y_test, y_pred))
    print(accuracy_score(y_test, y_pred,normalize=False))'''
    psymptoms = [Symptom1.get(),Symptom2.get(),Symptom3.get(),Symptom4.get(),Symptom5.get()]
    c=0
    a=50
    for z in psymptoms:
        for k in range(0,len(l1)):
            if(z==l1[k]):
                l2[k]=1
                c+=1
    if(c!=0):
        inputtest = [l2]
        predict = clf2.predict(inputtest)
        predicted=predict[0]
        h='no'
        for a in range(0,len(disease)):
            if(predicted == a):
                h='yes'
                break
        if (h=='yes'):
            t2.delete("1.0", END)
            t2.insert(END, disease[a])
        else:
            t2.delete("1.0", END)
            t2.insert(END, "Not Found")
    else:
        t2.delete("1.0", END)
        t2.insert(END, "Select the Symptoms")
    if(a!=50):
        return disease[a]
    return "Select the Symptoms"
#--Naive Bayes---------------------------------------------------------------------------------------
def NaiveBayes():
    '''from sklearn.naive_bayes import GaussianNB
    clf3 = GaussianNB()
    clf3=clf3.fit(X,np.ravel(y))
    # calculating accuracy-------------------------------------------------------------------
    from sklearn.metrics import accuracy_score
    y_pred=clf3.predict(X_test)
    print("Accuracy for NaiveBayes",accuracy_score(y_test, y_pred))
    print(accuracy_score(y_test, y_pred,normalize=False))'''
    # -----------------------------------------------------
    psymptoms = [Symptom1.get(),Symptom2.get(),Symptom3.get(),Symptom4.get(),Symptom5.get()]
    c=0
    for z in psymptoms:
        # print (k,)
        for k in range(0,len(l1)):
            if(z==l1[k]):
                l2[k]=1
                c+=1
    if(c!=0):
        inputtest = [l2]
        predict = clf3.predict(inputtest)
        predicted=predict[0]
        h='no'
        for a in range(0,len(disease)):
            if(predicted == a):
                h='yes'
                break
        if (h=='yes'):
            t3.delete("1.0", END)
            t3.insert(END, disease[a])
        else:
            t3.delete("1.0", END)
            t3.insert(END, "Not Found")
    else:
        t3.delete("1.0", END)
        t3.insert(END, "Select the Symptoms")
#----Logistic Regression--------------------------------------------------------------------------------------------
def LogisticRegression():
    global logitdisease
    '''from sklearn.linear_model import LogisticRegression
    clf4 = LogisticRegression()  # empty model of the Logistic Regression
    clf4 = clf4.fit(X, np.ravel(y))
    # calculating accuracy-------------------------------------------------------------------
    from sklearn.metrics import accuracy_score
    y_pred=clf4.predict(X_test)
    print("Accuracy for LogisticRegression",accuracy_score(y_test, y_pred))
    print(accuracy_score(y_test, y_pred,normalize=False))'''
    # -----------------------------------------------------
    psymptoms = [Symptom1.get(),Symptom2.get(),Symptom3.get(),Symptom4.get(),Symptom5.get()]
    c=0
    a=50
    for z in psymptoms:
        # print (k,)
        for k in range(0,len(l1)):
            if(z==l1[k]):
                l2[k]=1
                c+=1
    if(c!=0):
        inputtest = [l2]
        predict = clf4.predict(inputtest)
        predicted=predict[0]
        h='no'
        for a in range(0,len(disease)):
            if(predicted == a):
                h='yes'
                break
        if (h=='yes'):
            t4.delete("1.0", END)
            t4.insert(END, disease[a])
        else:
            t4.delete("1.0", END)
            t4.insert(END, "Not Found")
    else:
        t4.delete("1.0", END)
        t4.insert(END, "Select the Symptoms")
    if(a!=50):
        return disease[a]
    else:
        return "Select the Symptoms"
#---Support Vector Machine-------------------------------------------------------------------------------
def SVC():
    global svcdisease
    '''from sklearn.svm import SVC
    clf5 = SVC()  # empty model of the SVM
    clf5 = clf5.fit(X, y)
    # calculating accuracy-------------------------------------------------------------------
    from sklearn.metrics import accuracy_score
    y_pred=clf5.predict(X_test)
    print("Accuracy for SVC",accuracy_score(y_test, y_pred))
    print(accuracy_score(y_test, y_pred,normalize=False))'''
    # -----------------------------------------------------
    psymptoms = [Symptom1.get(),Symptom2.get(),Symptom3.get(),Symptom4.get(),Symptom5.get()]
    c=0
    for z in psymptoms:
        for k in range(0,len(l1)):
            if(z==l1[k]):
                l2[k]=1
                c+=1
    a=50
    if(c!=0):
        inputtes = [l2]
        predict = clf5.predict(inputtest)
        predicted=predict[0]
        h='no'
        for a in range(0,len(disease)):
            if(predicted == a):
                h='yes'
                break
        if (h=='yes'):
            t5.delete("1.0", END)
            t5.insert(END, disease[a])
        else:
            t5.delete("1.0", END)
            t5.insert(END, "Not Found")
    else:
        t5.delete("1.0", END)
        t5.insert(END, "Select the Symptoms")
    if(a!=50):
        return disease[a]
    return "Select the Symptoms" 
#---Final Disease Prediction-----------------------------------------------------------------------------
def disPred():
    log=LogisticRegression()
    rand=randomforest()
    supvm=SVC()
    if(log==rand):
        dis=log
    elif(rand==supvm):
        dis=rand
    elif(log==supvm):
        dis=log
    else:
        dis=rand
    t6.delete('1.0',END)
    t6.insert(END,dis)
    
# gui_code------------------------------------------------------------------------------------

root = Tk()
root.title("Drug Predictor using Machine Learning")
root.configure(background='pink')

# entry variables
Symptom1 = StringVar()
Symptom1.set(None)
Symptom2 = StringVar()
Symptom2.set(None)
Symptom3 = StringVar()
Symptom3.set(None)
Symptom4 = StringVar()
Symptom4.set(None)
Symptom5 = StringVar()
Symptom5.set(None)
Name = StringVar()

# Heading
w2 = Label(root, justify='center', text="Disease Prediction Using Machine Learning", fg="white", bg="red")
w2.config(font=("Elephant", 30))
w2.grid(row=1, column=0, columnspan=2, padx=100)

# labels
NameLb = Label(root, text="Name of the Patient", fg="yellow", bg="black")
NameLb.grid(row=6, column=0, pady=15, sticky=W)


S1Lb = Label(root, text="Symptom 1", fg="yellow", bg="black")
S1Lb.grid(row=7, column=0, pady=10, sticky=W)

S2Lb = Label(root, text="Symptom 2", fg="yellow", bg="black")
S2Lb.grid(row=8, column=0, pady=10, sticky=W)

S3Lb = Label(root, text="Symptom 3", fg="yellow", bg="black")
S3Lb.grid(row=9, column=0, pady=10, sticky=W)

S4Lb = Label(root, text="Symptom 4", fg="yellow", bg="black")
S4Lb.grid(row=10, column=0, pady=10, sticky=W)

S5Lb = Label(root, text="Symptom 5", fg="yellow", bg="black")
S5Lb.grid(row=11, column=0, pady=10, sticky=W)



lrLb = Label(root, text="LogisticRegression", fg="white", bg="blue")
lrLb.grid(row=16, column=0, pady=10,sticky=W)


supvm = Label(root, text="SupportVectorMachine", fg="white", bg="blue")
supvm.grid(row=18, column=0, pady=10, sticky=W)

decT = Label(root, text="DecisionTree", fg="white", bg="blue")
decT.grid(row=20, column=0, pady=10, sticky=W)

ranfo = Label(root, text="random forest", fg="white", bg="blue")
ranfo.grid(row=22, column=0, pady=10, sticky=W)

NB = Label(root, text="NaiveBayes", fg="white", bg="blue")
NB.grid(row=24, column=0, pady=10, sticky=W)

dispre = Label(root, text="Final Disease Prediction", fg="white", bg="blue")
dispre.grid(row=26, column=0, pady=10, sticky=W)

# entries
OPTIONS = sorted(l1)

NameEn = Entry(root, textvariable=Name)
NameEn.grid(row=6, column=1)

S1En = OptionMenu(root, Symptom1,*OPTIONS)
S1En.grid(row=7, column=1)

S2En = OptionMenu(root, Symptom2,*OPTIONS)
S2En.grid(row=8, column=1)

S3En = OptionMenu(root, Symptom3,*OPTIONS)
S3En.grid(row=9, column=1)

S4En = OptionMenu(root, Symptom4,*OPTIONS)
S4En.grid(row=10, column=1)

S5En = OptionMenu(root, Symptom5,*OPTIONS)
S5En.grid(row=11, column=1)


dst = Button(root, text="LogisticRegression", command=LogisticRegression,bg="dark blue",fg="yellow")
dst.grid(row=7, column=2,padx=10)

rnf = Button(root, text="SupportVectorMachine", command=SVC,bg="dark blue",fg="yellow")
rnf.grid(row=8, column=2,padx=10)

dc = Button(root, text="DecisionTree", command=DecisionTree,bg="dark blue",fg="yellow")
dc.grid(row=9, column=2,padx=10)

rf = Button(root, text="randomforest", command=randomforest,bg="dark blue",fg="yellow")
rf.grid(row=10, column=2,padx=10)

nf = Button(root, text="NaiveBayes", command=NaiveBayes,bg="dark blue",fg="yellow")
nf.grid(row=11, column=2,padx=10)

lr = Button(root, text="Final Disease Prediction", command=disPred,bg="dark blue",fg="yellow")
lr.grid(row=12, column=2,padx=10)

#textfileds
t1 = Text(root, height=1, width=40,bg="yellow",fg="dark red")
t1.grid(row=20, column=1, padx=10)

t2 = Text(root, height=1, width=40,bg="yellow",fg="dark red")
t2.grid(row=22, column=1 , padx=10)

t3 = Text(root, height=1, width=40,bg="yellow",fg="dark red")
t3.grid(row=24, column=1 , padx=10)

t4 = Text(root, height=1, width=40,bg="yellow",fg="dark red")
t4.grid(row=16, column=1 , padx=10)

t5 = Text(root, height=1, width=40,bg="yellow",fg="dark red")
t5.grid(row=18, column=1 , padx=10)

t6 = Text(root, height=1, width=40,bg="yellow",fg="dark red")
t6.grid(row=26, column=1 , padx=10)


root.mainloop()
